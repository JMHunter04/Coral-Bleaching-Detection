# %%
# Install core dependencies
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121  # GPU-enabled PyTorch
# !pip install timm opencv-python matplotlib numpy Pillow tqdm
# !pip install 'git+https://github.com/facebookresearch/detectron2.git'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/zhengziqiang/CoralSCOP
# %cd CoralSCOP

# %%
# bleached coral - JSON file
# !python test.py \
  --model_type vit_b \
  --checkpoint /content/drive/MyDrive/dissertation/checkpoints/vit_b_coralscop.pth \
  --iou_threshold 0.72 \
  --sta_threshold 0.62 \
  --test_img_path /content/drive/MyDrive/dissertation/dataset/bleached_corals \
  --output_path /content/drive/MyDrive/dissertation/dataset/segmenteddataset/bleached_coral \
  --gpu 0 \
  --point_number 32

# %%
# unbleached coral - JSON file
# !python test.py \
  --model_type vit_b \
  --checkpoint /content/drive/MyDrive/dissertation/checkpoints/vit_b_coralscop.pth \
  --iou_threshold 0.72 \
  --sta_threshold 0.62 \
  --test_img_path /content/drive/MyDrive/dissertation/dataset/healthy_corals \
  --output_path /content/drive/MyDrive/dissertation/dataset/segmenteddataset/healthy_coral \
  --gpu 0 \
  --point_number 32

# %%
# bleached coral - JPG file
# !python coralscop_visualization.py\
 --img_path /home/uwe-1/JHunter/coralscopIN/bleached_corals \
 --json_path /home/uwe-1/JHunter/coralscopOUT/bleached_corals \
 --output_path /home/uwe-1/JHunter/coralscopIMAGE/bleached_corals

# %%
# healthy coral - JPG file
# !python coralscop_visualization.py\
 --img_path /home/uwe-1/JHunter/coralscopIN/healthy_corals \
 --json_path /home/uwe-1/JHunter/coralscopOUT/healthy_corals \
 --output_path /home/uwe-1/JHunter/coralscopIMAGE/healthy_corals
